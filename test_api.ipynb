# %%
import requests

#local pc
#url = 'http://160.40.52.40:5000/api/validate'

#7S server
url = 'http://160.40.53.22:5000/api/validate'

# %%
data_test = {
  "datasource": "PWN-PREDICTION",
  "data": [
    {
      "date": "2024-02-25T00:00:00",
      "value": 68.6351902563
    },
    {
      "date": "2024-02-26T00:00:00",
      "value": 68.6725062039
    },
    {
      "date": "2024-02-27T00:00:00",
      "value": 66.9970943067
    }
  ],
  "location": {
        "type": "Point",
        "coordinates": [
        5.26505600000372,
        52.7503060000005
        ]
    },
}

# %%
response = requests.post(url, json=data_test)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'message': 'Data model is valid.'}
